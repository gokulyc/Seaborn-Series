# %% [markdown]
# ## 04. Distplots in Seaborn

# %% [markdown]
# ### Importing the libraries

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Loading the Penguins Dataset

# %%
penguins = sns.load_dataset('penguins')

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %% [markdown]
# ### Drawing a Simple distplot

# %%
sns.distplot(penguins.flipper_length_mm,rug = True)

# %% [markdown]
# The y axis gives the probability density function of the data

# %%
sns.distplot(penguins.body_mass_g,rug = True)

# %% [markdown]
# ### Removing the KDE Plot

# %% [markdown]
# differnt values for hist=True,kde=True,rug=False

# %%
sns.distplot(penguins.flipper_length_mm,hist = False)

# %% [markdown]
# ### Setting the number of bins

# %%
sns.distplot(penguins.flipper_length_mm,bins = 20)

# %% [markdown]
# ### Setting the bin values as array

# %%
sns.distplot(penguins.flipper_length_mm,bins = [160,170,180,190,200,240])

# %% [markdown]
# ### Fitting the data to a particular distribution using norm_hist

# %%
sns.distplot(penguins.flipper_length_mm,norm_hist = True,kde = False)

# %%
sns.distplot(penguins.flipper_length_mm,kde = False)

# %% [markdown]
# ### Styling Rugplots

# %%
sns.distplot(penguins.flipper_length_mm,rug_kws = {'color':'red','height':0.30},rug = True)

# %% [markdown]
# ### Styling Histograms

# %%
sns.distplot(penguins.flipper_length_mm,kde = False,hist_kws = {'color':'blue','alpha':0.3,'histtype':'stepfilled'})

# %%
sns.distplot(penguins.flipper_length_mm,kde = False,hist_kws = {'color':'blue','alpha':0.8,'histtype':'step'})

# %% [markdown]
# ### Styling KDE Plots

# %%
sns.distplot(penguins.flipper_length_mm,kde = True,hist = False,kde_kws = {'color':'red','lw':4.0,'alpha':0.8})
